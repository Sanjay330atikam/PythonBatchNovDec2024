# %% [markdown]
# ##OS MODULE

# %%
import os

# %%
dir(os)
# Out:
# ['CLD_CONTINUED',
#  'CLD_DUMPED',
#  'CLD_EXITED',
#  'CLD_KILLED',
#  'CLD_STOPPED',
#  'CLD_TRAPPED',
#  'CLONE_FILES',
#  'CLONE_FS',
#  'CLONE_NEWCGROUP',
#  'CLONE_NEWIPC',
#  'CLONE_NEWNET',
#  'CLONE_NEWNS',
#  'CLONE_NEWPID',
#  'CLONE_NEWUSER',
#  'CLONE_NEWUTS',
#  'CLONE_SIGHAND',
#  'CLONE_SYSVSEM',
#  'CLONE_THREAD',
#  'CLONE_VM',
#  'DirEntry',
#  'EFD_CLOEXEC',
#  'EFD_NONBLOCK',
#  'EFD_SEMAPHORE',
#  'EX_CANTCREAT',
#  'EX_CONFIG',
#  'EX_DATAERR',
#  'EX_IOERR',
#  'EX_NOHOST',
#  'EX_NOINPUT',
#  'EX_NOPERM',
#  'EX_NOUSER',
#  'EX_OK',
#  'EX_OSERR',
#  'EX_OSFILE',
#  'EX_PROTOCOL',
#  'EX_SOFTWARE',
#  'EX_TEMPFAIL',
#  'EX_UNAVAILABLE',
#  'EX_USAGE',
#  'F_LOCK',
#  'F_OK',
#  'F_TEST',
#  'F_TLOCK',
#  'F_ULOCK',
#  'GRND_NONBLOCK',
#  'GRND_RANDOM',
#  'GenericAlias',
#  'MFD_ALLOW_SEALING',
#  'MFD_CLOEXEC',
#  'MFD_HUGETLB',
#  'MFD_HUGE_16GB',
#  'MFD_HUGE_16MB',
#  'MFD_HUGE_1GB',
#  'MFD_HUGE_1MB',
#  'MFD_HUGE_256MB',
#  'MFD_HUGE_2GB',
# ...

# %%
print(os.__doc__)
# the below shown are the constants in OS directory.
# Out:
# OS routines for NT or Posix depending on what system we're on.
#
# This exports:
#   - all functions from posix or nt, e.g. unlink, stat, etc.
#   - os.path is either posixpath or ntpath
#   - os.name is either 'posix' or 'nt'
#   - os.curdir is a string representing the current directory (always '.')
#   - os.pardir is a string representing the parent directory (always '..')
#   - os.sep is the (or a most common) pathname separator ('/' or '\\')
#   - os.extsep is the extension separator (always '.')
#   - os.altsep is the alternate pathname separator (None or '/')
#   - os.pathsep is the component separator used in $PATH etc
#   - os.linesep is the line separator in text files ('\r' or '\n' or '\r\n')
#   - os.defpath is the default search path for executables
#   - os.devnull is the file path of the null device ('/dev/null', etc.)
#
# Programs that import and use 'os' stand a better chance of being
# portable between different platforms.  Of course, they must then
# ...

# %%
print(os.cpu_count())
# gives how many cores are there is system
print(f"There are {os.cpu_count()} cores in the system")
# Out:
# 2
# There are 2 cores in the system

# %%
# os.urandom - gives a randome bytes code for eg gives 10 random bytes
print(os.urandom(10))
print(f"Here is a 10-random byte code {str(os.urandom(10))}")
# this byte code always changes
# Out:
# b'p\xfa\xec\xd9\x88\xa8\x9748\xd8'
# Here is a 10-random byte code b'Kn\x99;\xab\xb8\xad\x16\x83\x87'

# %%
print (f"""
    {os.altsep =}
    {os.curdir =}
    {os.extsep =}
    {os.linesep =}
    {os.name =}     #anything apart from windows is linux
    {os.pardir =}
    {os.pathsep =}
    {os.sep =}
""")
# Out:
#     os.altsep =None
#     os.curdir ='.'
#     os.extsep ='.'
#     os.linesep ='\n'
#     os.name ='posix'     #anything apart from windows is linux
#     os.pardir ='..'
#     os.pathsep =':'
#     os.sep ='/'

# %%
os.name
# 'java','nt','posix' are the registered os names
# Out:
# 'posix'

# %%
os.devnull
# used when we want to suprass or nul value in command lines
#/dev/null - 'posix'
# null - 'windows'

# %%
os.defpath
# Out:
# '/bin:/usr/bin'

# %%
os.times()
# Out:
# posix.times_result(user=2.75, system=0.46, children_user=0.0, children_system=0.0, elapsed=17182033.67)

# %%
# os.urandom(10)
for i in range(0,10):
    print(i,os.urandom(10))
# Out:
# 0 b'\xef%\xd03\xc3Hhx\x05\x0c'
# 1 b'\xfa\x85\xd4_\x8f\x07\xd9a\x9aT'
# 2 b'\x9cR\x11\x16Q\x89\xd8\x13>k'
# 3 b'9\xf5\x7f\xd5(\x95m\xa7`K'
# 4 b'\x0e\x96\xc72BC\xfaHg\x8a'
# 5 b'L{\xc7+\x0c8n_9K'
# 6 b'+\x0e\x1e\xbc\xf2\x98^\xfcD\x82'
# 7 b'\x85,\xe8Tj\xf3T\x1dV\x9d'
# 8 b'\x19\x9f\xa0\xeb\xfaK\xadx\xad\xcc'
# 9 b'3\xdf\x85Zu\xbd6\xe5\x19\xe9'

# %%
os.environ # environment variables
# Out:
# environ{'DOCKER_BUILDKIT': '1',
#         'ENABLE_DYNAMIC_INSTALL': 'true',
#         'LESSOPEN': '| /usr/bin/lesspipe %s',
#         'GITHUB_TOKEN': 'ghu_PixhDwvjFSXpfpvJSBORcoxK6yhi8u0zV2Vf',
#         'PYTHONIOENCODING': 'UTF-8',
#         'GITHUB_CODESPACE_TOKEN': 'BLLYV4FCJYJ4YFXTNSBLAXLHPFDPNANCNFSM4AKK6LDQ',
#         'USER': 'codespace',
#         'RVM_PATH': '/usr/local/rvm',
#         'NVS_ROOT': '/usr/local/nvs',
#         'HOSTNAME': 'codespaces-f91a93',
#         'DOTNET_USE_POLLING_FILE_WATCHER': 'true',
#         'CONDA_SCRIPT': '/opt/conda/etc/profile.d/conda.sh',
#         'PIPX_HOME': '/usr/local/py-utils',
#         'SHLVL': '1',
#         'GITHUB_CODESPACES_PORT_FORWARDING_DOMAIN': 'app.github.dev',
#         'HUGO_ROOT': '/home/codespace/.hugo',
#         'HOME': '/home/codespace',
#         'OLDPWD': '/vscode/bin/linux-x64/65edc4939843c90c34d61f4ce11704f09d3e5cb6',
#         'ORYX_ENV_TYPE': 'vsonline-present',
# ...

# %%
print(os.getenv("PYTHON_PATH","No set Yet"))
# python path by default check modules what modules we have installed

# export PYTHONSTARTUP=path/to/your/script.py-'linux'
# Set    PYTHONSTARTUP=path\to\your\script.py-'Windows'

# in this getenv we can specific the whatever the path we have
print(os.getenv("PYTHONSTARTUP","No set Yet"))
# Out:
# /usr/local/python/current
# No set Yet

# %%
# Adding a new environement variable
os.environ['A'] ='Apple'# environ: modifies the environment variables
os.getenv("A",'No such key')
# Out:
# 'Apple'

# %%
for each_path in sorted(os.get_exec_path()):
    print(each_path)
# Out:
# /bin
# /go/bin
# /home/codespace/.dotnet
# /home/codespace/.dotnet/tools
# /home/codespace/.local/bin
# /home/codespace/.local/bin
# /home/codespace/.php/current/bin
# /home/codespace/.python/current/bin
# /home/codespace/.ruby/current/bin
# /home/codespace/java/current/bin
# /home/codespace/nvm/current/bin
# /opt/conda/bin
# /sbin
# /usr/bin
# /usr/local/bin
# /usr/local/go/bin
# /usr/local/hugo/bin
# /usr/local/nvs
# /usr/local/oryx
# /usr/local/php/current/bin
# /usr/local/py-utils/bin
# /usr/local/python/current/bin
# /usr/local/rvm/bin
# /usr/local/rvm/gems/default/bin
# /usr/local/rvm/gems/default@global/bin
# /usr/local/rvm/rubies/default/bin
# /usr/local/sbin
# /usr/local/sdkman/bin
# /usr/local/sdkman/candidates/ant/current/bin
# /usr/local/sdkman/candidates/gradle/current/bin
# /usr/local/sdkman/candidates/java/current/bin
# /usr/local/sdkman/candidates/maven/current/bin
# /usr/local/share/nvm/current/bin
# /usr/local/share/rbenv/bin
# /usr/sbin
# /usr/share/dotnet
# ...

# %%
import getpass
assert(getpass.getuser()
       == os.environ['USER']
       == os.getenv('USER')
)

# %%
getpass.getuser(),os.environ['USER']
# Out:
# ('codespace', 'codespace')

# %%
os.getpid()
# This returns the parents processor id.
# Out:
# 25098

# %%
os.getcwd()# gives current wirking directory
# Out:
# '/workspaces/PythonBatchNovDec2024/OS_module'

# %%
print('my\newfolder')
# Out:
# my
# ewfolder

# %%
print('my\\newfolder')
# Out:
# my\newfolder

# %%
print(r'my\newfolder')
# Out:
# my\newfolder

# %%
print('my/new/folder/path')# 'Postix' - path works in NT also
# Out:
# my/new/folder/path

# %%
os.getcwd()
# Out:
# '/workspaces/PythonBatchNovDec2024/OS_module'

# %%
os.listdir()
# Out:
# ['os_module.ipynb']

# %%
os.listdir('.')#current directoary
# Out:
# ['os_module.ipynb']

# %%
os.listdir(os.curdir)
# Out:
# ['os_module.ipynb']

# %%
os.listdir('..')# gives parent directoary
# Out:
# ['Iterables',
#  'Loops',
#  'venv',
#  '__pycache__',
#  '.git',
#  'OS_module',
#  '.gitignore',
#  'iterators',
#  'Basics',
#  'README.md',
#  'Conditional Operations']

# %%
os.listdir(os.pardir)
# Out:
# ['Iterables',
#  'Loops',
#  'venv',
#  '__pycache__',
#  '.git',
#  'OS_module',
#  '.gitignore',
#  'iterators',
#  'Basics',
#  'README.md',
#  'Conditional Operations']

# %%
assert(os.listdir('..') == os.listdir(os.pardir))

# %%
os.listdir('../..')# levels of directoary 1st level
# Out:
# ['PythonBatchNovDec2024', '.oryx', '.codespaces']

# %%
os.listdir('../../..')# 2nd level
# Out:
# ['var',
#  'media',
#  'proc',
#  'sys',
#  'boot',
#  'run',
#  'srv',
#  'libx32',
#  'root',
#  'dev',
#  'etc',
#  'tmp',
#  'sbin',
#  'lib32',
#  'opt',
#  'mnt',
#  'lib',
#  'lib64',
#  'bin',
#  'home',
#  'usr',
#  'vscode',
#  '.codespaces',
#  'workspaces',
#  '.dockerenv',
#  'go']

# %%
os.listdir('../../../..')
# Out:
# ['var',
#  'media',
#  'proc',
#  'sys',
#  'boot',
#  'run',
#  'srv',
#  'libx32',
#  'root',
#  'dev',
#  'etc',
#  'tmp',
#  'sbin',
#  'lib32',
#  'opt',
#  'mnt',
#  'lib',
#  'lib64',
#  'bin',
#  'home',
#  'usr',
#  'vscode',
#  '.codespaces',
#  'workspaces',
#  '.dockerenv',
#  'go']

# %%
os.getcwd()# current working directoary
# Out:
# '/workspaces/PythonBatchNovDec2024/OS_module'

# %%
os.listdir()
# Out:
# ['os_module.ipynb']

# %%
os.chdir('/workspaces/PythonBatchNovDec2024/OS_module')
#chnaging the directory by mentioning the path for directory in Brackets

# %%
os.getcwd()
# Out:
# '/workspaces/PythonBatchNovDec2024/OS_module'

# %%
os.scandir(os.getcwd())# scanning the directoary.

# %%
os.lstat('.')#asking the stats of current directoay'.'!
# Out:
# os.stat_result(st_mode=16895, st_ino=1835538, st_dev=1796, st_nlink=2, st_uid=1000, st_gid=1000, st_size=4096, st_atime=1735958777, st_mtime=1735958776, st_ctime=1735958776)

# %% [markdown]
# ##Working with Paths()

# %%
print (f"""
    {os.altsep =}
    {os.curdir =}
    {os.extsep =}
    {os.name =}     #anything apart from windows is linux
    {os.pardir =}
    {os.pathsep =}
    {os.sep =}
""")
# Out:
#     os.altsep =None
#     os.curdir ='.'
#     os.extsep ='.'
#     os.name ='posix'     #anything apart from windows is linux
#     os.pardir ='..'
#     os.pathsep =':'
#     os.sep ='/'

# %%
os.linesep # tells how lines were seperated
# Out:
# '\n'

# %% [markdown]
# ## Working With Directories and Folders()

# %%
os.mkdir('my folder')# creates a folder
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 os.mkdir('my folder')
#
# FileExistsError: [Errno 17] File exists: 'my folder'

# %%
os.listdir('.')
# Out:
# ['os_module.ipynb', 'my folder']

# %%
os.makedirs('my folder',exist_ok=True)
# does graceful stop and doesnot give error even though my folder is already present.

# %%
os.makedirs('First/Second/Third',exist_ok=True)
# creates multpile folders

# %%
os.listdir()
# Out:
# ['First', 'os_module.ipynb', 'my folder']

# %%
os.system('tree') # tree command showing the directory structure
# Out:
# .
# ├── First
# │   └── Second
# │       └── Third
# ├── my folder
# └── os_module.ipynb
#
# 4 directories, 1 file
# 0

# %%
# creating a file
f =open('myfile.text','w')# file name, and write mode in brackets
f.write('my data')
f.close()

# %%
os.listdir()
# Out:
# ['myfile.text', 'First', 'os_module.ipynb', 'my folder']

# %%
# renamin a file
os.rename('myfile.text','otherfile.tst')

# %%
os.listdir()
# Out:
# ['First', 'os_module.ipynb', 'my folder', 'otherfile.tst']

# %%
# we can alos rename the folder
os.rename('First','Python Folder')

# %%
os.listdir()
# Out:
# ['Python Folder', 'os_module.ipynb', 'my folder', 'otherfile.tst']

# %%
os.system('tree')
# Out:
# .
# ├── Python Folder
# │   └── Second
# │       └── Third
# ├── my folder
# ├── os_module.ipynb
# └── otherfile.tst
#
# 4 directories, 2 files
# 0

# %%
#assignment - try os.renames

# %%
os.remove('otherfile.tst')#removes file
# Out:
# ['Python Folder', 'os_module.ipynb', 'my folder']

# %%
# can't removes folder
os.remove('my\ folder')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\ '
# <>:2: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipykernel_2536/4263925926.py:2: SyntaxWarning: invalid escape sequence '\ '
#   os.remove('my\ folder')
# /tmp/ipykernel_2536/4263925926.py:2: SyntaxWarning: invalid escape sequence '\ '
#   os.remove('my\ folder')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 # can't removes folder
# ----> 2 os.remove('my\ folder')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'my\\ folder'

# %%
os.rmdir('my folder')# removes folder

# %%
os.listdir()
# Out:
# ['Python Folder', 'os_module.ipynb']

# %%
os.system('tree')
# Out:
# .
# ├── Python Folder
# │   └── Second
# │       └── Third
# └── os_module.ipynb
#
# 3 directories, 1 file
# 0

# %%
os.removedirs('Python Folder/Second/Third')
# removes Python Folder/Second/Third
# then Python Folder/Second
# then Python Folder

# %%
os.system('tree')
# Out:
# .
# └── os_module.ipynb
#
# 0 directories, 1 file
# 0

# %% [markdown]
# ### Executing Commands

# %%
os.system('ipconfig') # 1 means unsucsessfull command
# Out:
# sh: 1: ipconfig: not found
# 32512

# %%
os.system('ifconfig')# 0 means sucsessfull command
# Out:
# docker0: flags=4099<UP,BROADCAST,MULTICAST>  mtu 1500
#         inet 172.17.0.1  netmask 255.255.0.0  broadcast 172.17.255.255
#         ether 02:42:e6:02:0b:c2  txqueuelen 0  (Ethernet)
#         RX packets 0  bytes 0 (0.0 B)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 0  bytes 0 (0.0 B)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# eth0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet 10.0.0.199  netmask 255.255.0.0  broadcast 10.0.255.255
#         inet6 fe80::7e1e:52ff:fe3e:79ca  prefixlen 64  scopeid 0x20<link>
#         ether 7c:1e:52:3e:79:ca  txqueuelen 1000  (Ethernet)
#         RX packets 17361158  bytes 24107014046 (24.1 GB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 473575  bytes 160952072 (160.9 MB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# lo: flags=73<UP,LOOPBACK,RUNNING>  mtu 65536
#         inet 127.0.0.1  netmask 255.0.0.0
# ...

# %%
os.system('Ping google.com')# ping is not found because it doesnot support operating SYstem
# Out:
# sh: 1: Ping: not found
# 32512

# %% [markdown]
# ####Get all Python Files in our MAterial

# %%
os.listdir('../../')
# Out:
# ['PythonBatchNovDec2024', '.oryx', '.codespaces']

# %%
os.listdir('../../PythonBatchNovDec2024')
# Out:
# ['Iterables',
#  'Loops',
#  'venv',
#  '__pycache__',
#  '.git',
#  'OS_module',
#  '.gitignore',
#  'iterators',
#  'Basics',
#  'README.md',
#  'Conditional Operations']

# %%
#os.walk()
os.walk('../../PythonBatchNovDec2024')
# Out:
# <generator object walk at 0x750e9898a5a0>

# %%
# generator object can be accessed by for loop
for each in os.walk('.'):
    print(len(each),each )# it gives current , lisputt of directory and list of files in out
    break
# Out:
# 3 ('.', [], ['os_module.ipynb'])

# %%
for each_dir,list_of_folder,list_of_files in os.walk('../../PythonBatchNovDec2024'):
    print(each_dir)
# this gives all directories but in random order
# Out:
# ../../PythonBatchNovDec2024
# ../../PythonBatchNovDec2024/Iterables
# ../../PythonBatchNovDec2024/Loops
# ../../PythonBatchNovDec2024/Loops/__pycache__
# ../../PythonBatchNovDec2024/venv
# ../../PythonBatchNovDec2024/venv/lib
# ../../PythonBatchNovDec2024/venv/lib/python3.12
# ../../PythonBatchNovDec2024/venv/lib/python3.12/site-packages
# ../../PythonBatchNovDec2024/venv/lib/python3.12/site-packages/pure_eval
# ../../PythonBatchNovDec2024/venv/lib/python3.12/site-packages/pure_eval/__pycache__
# ../../PythonBatchNovDec2024/venv/lib/python3.12/site-packages/traitlets-5.14.3.dist-info
# ../../PythonBatchNovDec2024/venv/lib/python3.12/site-packages/traitlets-5.14.3.dist-info/licenses
# ../../PythonBatchNovDec2024/venv/lib/python3.12/site-packages/asttokens-3.0.0.dist-info
# ../../PythonBatchNovDec2024/venv/lib/python3.12/site-packages/traitlets
# ../../PythonBatchNovDec2024/venv/lib/python3.12/site-packages/traitlets/config
# ...

# %%
for each_dir,list_of_folder,list_of_files in os.walk('../../PythonBatchNovDec2024'):
    if list_of_folder:
     print(list_of_folder)
     # displays first list of folders.!!
# Out:
# ['Iterables', 'Loops', 'venv', '__pycache__', '.git', 'OS_module', 'iterators', 'Basics', 'Conditional Operations']
# ['__pycache__']
# ['lib', 'share', 'bin']
# ['python3.12']
# ['site-packages']
# ...

# %%
for each_dir,list_of_folder,list_of_files in os.walk('../../PythonBatchNovDec2024'):
     if list_of_files:
      print(list_of_files)
# Out:
# ['.gitignore', 'README.md']
# ['iterables.ipynb']
# ['progress_bar.cpython-312.pyc']
# ['CACHEDIR.TAG', '.gitignore', 'pyvenv.cfg']
# ['pip-24.3.1.virtualenv', '_virtualenv.py', 'ipykernel_launcher.py', '_virtualenv.pth', 'six.py', 'jupyter.py', 'decorator.py', 'nest_asyncio.py']
# ['my_getattr_static.py', '__init__.py', 'utils.py', 'core.py', 'py.typed', 'version.py']
# ['utils.cpython-312.pyc', 'core.cpython-312.pyc', 'version.cpython-312.pyc', '__init__.cpython-312.pyc', 'my_getattr_static.cpython-312.pyc']
# ['RECORD', 'INSTALLER', 'WHEEL', 'METADATA']
# ['LICENSE']
# ['RECORD', 'INSTALLER', 'top_level.txt', 'WHEEL', 'LICENSE', 'METADATA']
# ['__init__.py', 'py.typed', 'log.py', '_version.py', 'traitlets.py']
# ['argcomplete_config.py', '__init__.py', 'application.py', 'configurable.py', 'loader.py', 'manager.py', 'sphinxdoc.py']
# ...

# %%
#list all python files that iam working 
for each_dir,list_of_folder,list_of_files in os.walk('../../PythonBatchNovDec2024'):
     if list_of_files:
      for each_file in list_of_files:
       file_name, file_extn =os.path.splitext(each_file)# it will seperate extension with the main file.
       if file_extn =='.py':
            print(each_file)
# Out:
# _virtualenv.py
# ipykernel_launcher.py
# six.py
# jupyter.py
# decorator.py
# nest_asyncio.py
# my_getattr_static.py
# __init__.py
# utils.py
# core.py
# version.py
# __init__.py
# log.py
# _version.py
# traitlets.py
# argcomplete_config.py
# __init__.py
# application.py
# configurable.py
# loader.py
# manager.py
# sphinxdoc.py
# importstring.py
# __init__.py
# warnings.py
# nested_update.py
# sentinel.py
# decorators.py
# text.py
# getargspec.py
# bunch.py
# descriptions.py
# test_traitlets.py
# __init__.py
# utils.py
# clientabc.py
# connect.py
# channelsabc.py
# __init__.py
# utils.py
# runapp.py
# consoleapp.py
# restarter.py
# launcher.py
# channels.py
# threaded.py
# jsonutil.py
# kernelapp.py
# localinterfaces.py
# adapter.py
# kernelspecapp.py
# client.py
# managerabc.py
# multikernelmanager.py
# win_interrupt.py
# kernelspec.py
# _version.py
# session.py
# manager.py
# __init__.py
# tunnel.py
# forward.py
# __init__.py
# client.py
# __init__.py
# local_provisioner.py
# ...

# %%
py_files = []
jupiter_notebook_files = []
for each_dir,list_of_folder,list_of_files in os.walk('../../PythonBatchNovDec2024'):
     if list_of_files:
      for each_file in list_of_files:
       file_name, file_extn =os.path.splitext(each_file)
       if file_extn =='.py':
            py_files.append(each_file)
       elif file_extn == '.ipynb':
          jupiter_notebook_files.append(each_file)

print(f"In this course they are {len(py_files)}python files and {len(jupiter_notebook_files)}jupiter notebook files.!")
# Out:
# In this course they are 1889python files and 6jupiter notebook files.!

# %%
#assignment

# %% [markdown]
# ###Workinng with Paths()

# %%
os.path.basename('home/user/temp.txt')
# this returns basename(temp.txt) doesnot check presence of file

# %%
os.path.dirname('home/user/temp.txt')
# returns the directory name
# Out:
# 'home/user'

# %%
os.path.abspath('temp.txt')
# it will add the current directory for 'temp.txt'
# Out:
# '/workspaces/PythonBatchNovDec2024/OS_module/temp.txt'

# %%
os.path.realpath('home/user/temp.txt')
# returns as it is.!
# Out:
# '/workspaces/PythonBatchNovDec2024/OS_module/home/user/temp.txt'

# %%
os.path.splitext('home/user/temp.log')
# it just seperates
# Out:
# ('home/user/temp', '.log')

# %%
os.path.splitdrive('home/user/temp.txt')
# Out:
# ('', 'home/user/temp.txt')

# %%
os.path.join('css','america')
# this will join
# Out:
# 'css/america'

# %%
os.path.join('css','america','html','text','py')
# Out:
# 'css/america/html/text/py'

# %%
'\\'.join(('css','america','html','text','py'))
# Out:
# 'css\\america\\html\\text\\py'

# %%
(os.sep).join(('css','america','html','text','py'))
# Out:
# 'css/america/html/text/py'

# %%
new_path = os.path.join('css','america','html','text','py')
new_path
# Out:
# 'css/america/html/text/py'

# %%
os.makedirs(new_path,exist_ok=False)

# %%
os.system('tree')
# Out:
# .
# ├── css
# │   └── america
# │       └── html
# │           └── text
# │               └── py
# └── os_module.ipynb
#
# 5 directories, 1 file
# 0

# %%
os.path.getsize('css')
# Out:
# 4096

# %%
os.path.getctime('css')
# Out:
# 1736051089.4932237

# %%
os.stat('css')
# Out:
# os.stat_result(st_mode=16895, st_ino=1835672, st_dev=1798, st_nlink=3, st_uid=1000, st_gid=1000, st_size=4096, st_atime=1736051094, st_mtime=1736051089, st_ctime=1736051089)

# %%
os.stat('css').st_ctime
# Out:
# 1736051089.4932237

# %% [markdown]
# ## Attributes Which Work only on Linux()

# %%
#os.getloadavg
#- This function retursn the system load average in last 1-15 minutes.
os.getloadavg()
# Out:
# (0.76, 0.49, 0.37)

# %%
#os.statvfs()
#- This function returns information of file such as total size, free space etc.

os.statvfs('css')
# Out:
# os.statvfs_result(f_bsize=4096, f_frsize=4096, f_blocks=8211920, f_bfree=5411534, f_bavail=4988010, f_files=2097152, f_ffree=1786575, f_favail=1786575, f_flag=4100, f_namemax=255)

# %%
os.pipe()
# - This creates a pair of connected file descriptorsf
# Out:
# (67, 70)

# %%
os.chroot()
